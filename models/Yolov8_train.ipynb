# %%
import torch
print(torch.cuda.is_available())  # True이면 GPU가 활성화된 상태
# Out:
# True

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 47.7 MB/s eta 0:00:00
# ...

# %%
import torch
torch.cuda.empty_cache()  # GPU 메모리 정리

# %%
from ultralytics import YOLO

# YOLOv8 모델 로드
model = YOLO('yolov8s.pt')  # yolov8s.pt는 작은 모델로, 다른 모델(예: yolov8m.pt, yolov8l.pt 등)도 선택 가능

# 학습을 위한 설정
model.train(
    data='../data.yaml',  # data.yaml 파일 경로
    epochs=100,  # 학습할 에폭 수
    imgsz=1280,  # 이미지 크기
    batch=16,  # 배치 크기
    device='0',  # 사용할 GPU (0번 GPU 사용, CPU로 학습하려면 'cpu')
    name='yolov8_billiard',  # 학습 결과를 저장할 폴더 이름
    workers=4  # 데이터 로딩을 위한 워커 수
)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
